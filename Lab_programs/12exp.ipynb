# %%
sentence = input("Enter sentence: ")

words = sentence.lower().split()

determiners = ["the", "a"]
nouns = ["boy", "girl", "dog", "cat"]
verbs = ["sees", "likes", "eats"]

if len(words) == 5:

    if (words[0] in determiners and
        words[1] in nouns and
        words[2] in verbs and
        words[3] in determiners and
        words[4] in nouns):

        print("Sentence Accepted")

    else:
        print("Sentence Rejected")

else:
    print("Sentence Rejected")
# Out:
# Enter sentence: the boy sees a dog
# Sentence Accepted
