# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

n = int(input("Enter number of documents: "))

documents = []

for i in range(n):
    text = input("Enter document " + str(i + 1) + ": ")
    documents.append(text)

query = input("Enter search query: ")

vectorizer = TfidfVectorizer()

data = documents + [query]

matrix = vectorizer.fit_transform(data)

scores = cosine_similarity(matrix[-1], matrix[:-1])

for i in range(n):
    print("Document", i + 1, "Score:", round(scores[0][i], 2))

best = scores[0].argmax()

print("Most Relevant Document:")
print(documents[best])
# Out:
# Enter number of documents: 3
# Enter document 1: Machine learning uses Python
# Enter document 2: Python is a programming language
# Enter document 3: Cricket is a popular sport
# Enter search query: Python programming
# Document 1 Score: 0.22
# Document 2 Score: 0.62
# Document 3 Score: 0.0
# Most Relevant Document:
# Python is a programming language
