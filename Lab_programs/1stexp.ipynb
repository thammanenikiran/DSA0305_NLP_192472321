# %%
import re

text = input("Enter a text: ")
pattern = input("Enter the word or pattern to search: ")

# Perform a case-insensitive search
result = re.search(pattern, text, re.IGNORECASE)

if result:
    print("Pattern found")
    print("Matched text:", result.group())
else:
    print("Pattern not found")
# Out:
# Enter a text: python is the easy program
# Enter the word or pattern to search: python
# Pattern found
# Matched text: python
