# %%
import nltk
from nltk.corpus import wordnet
nltk.download('wordnet')
nltk.download('omw-1.4')
word ="bike"
synsets=wordnet.synsets(word)
print("word: ",word)
print("number of synsets",len(synsets))
for synset in synsets:
    print("\nsynset :",synset.name())
    print("defination",synset.definition())
    print("example",synset.examples())

    synonyms=synset.lemmas()
    print("synonyms:",[lemma.name() for lemma in synonyms])
# Out:
# word:  bike
# number of synsets 3
#
# synset : motorcycle.n.01
# defination a motor vehicle with two wheels and a strong frame
# example []
# synonyms: ['motorcycle', 'bike']
#
# synset : bicycle.n.01
# defination a wheeled vehicle that has two wheels and is moved by foot pedals
# example []
# synonyms: ['bicycle', 'bike', 'wheel', 'cycle']
#
# synset : bicycle.v.01
# defination ride a bicycle
# example []
# synonyms: ['bicycle', 'cycle', 'bike', 'pedal', 'wheel']
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
